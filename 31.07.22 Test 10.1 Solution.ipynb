# %% [markdown]
# # Task1 - FitBit_DATA

# %% [markdown]
# # Q1) Read this data set in pandas, mysql and mongodb

# %% [markdown]
# # For MySQL

# %%
import MySQLdb
import csvkit

# !csvsql --db mysql://root:sahil1234@127.0.0.1:3306/fit2 --insert FitBit_data.csv

# %%
from IPython.display import Image
Image(filename= 'G:\\Udemy\\DATA SCIENCE ineuron\\Tasts given by sudhanshu\\Task 10 Images\\01.mysql.JPG', width = 800, height=800)

# %% [markdown]
# # For pandas

# %%
import pandas as pd
fitkit_data = pd.read_csv('G:\\Udemy\\DATA SCIENCE ineuron\\Resources\\24.07.2022 pandas resources\\31.07.2022 Pandas\\FitBit data.csv')

# %%
fitkit_data.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %% [markdown]
# # For mongoDB

# %%
# 1st comvert csv file to json using pandas
fitkit_data.to_json('fitkit_data_jason')

# %%
from IPython.display import Image
Image(filename= 'G:\\Udemy\\DATA SCIENCE ineuron\\Tasts given by sudhanshu\\Task 10 Images\\01_pycharm.JPG', width = 1000, height=1000)

# %%
from IPython.display import Image
Image(filename= 'G:\\Udemy\\DATA SCIENCE ineuron\\Tasts given by sudhanshu\\Task 10 Images\\01_mongodb.png', width = 800, height=800)

# %% [markdown]
# # Read data from mongodb

# %%
import pymongo
client = pymongo.MongoClient("mongodb+srv://sahil_josan:samongodbhil5@cluster0.sptya9h.mongodb.net/?retryWrites=true&w=majority")
db = client.test

database = client['test10_database']
collection = database['fitkit_data']
#collection.insert_one(converted_fitkit_data)

record1 = collection.find()
for i in record1:
    print(i)
# Out:
# {'_id': ObjectId('6305334363dfd582a916feb9'), 'Id': {'0': 1503960366, '1': 1503960366, '2': 1503960366, '3': 1503960366, '4': 1503960366, '5': 1503960366, '6': 1503960366, '7': 1503960366, '8': 1503960366, '9': 1503960366, '10': 1503960366, '11': 1503960366, '12': 1503960366, '13': 1503960366, '14': 1503960366, '15': 1503960366, '16': 1503960366, '17': 1503960366, '18': 1503960366, '19': 1624580081, '20': 1624580081, '21': 1624580081, '22': 1624580081, '23': 1624580081, '24': 1624580081, '25': 1624580081, '26': 1624580081, '27': 1624580081, '28': 1624580081, '29': 1624580081, '30': 1624580081, '31': 1624580081, '32': 1624580081, '33': 1624580081, '34': 1624580081, '35': 1624580081, '36': 1624580081, '37': 1624580081, '38': 1644430081, '39': 1644430081, '40': 1644430081, '41': 1644430081, '42': 1644430081, '43': 1644430081, '44': 1644430081, '45': 1644430081, '46': 1644430081, '47': 1644430081, '48': 1844505072, '49': 1844505072, '50': 1844505072, '51': 1844505072, '52': 1844505072, '
# ...

# %% [markdown]
# # Q3) Convert all the dates available in dataset to timestamp format in pandas

# %%
fitkit_data['ActivityDate'] = fitkit_data['ActivityDate'].astype('datetime64[ns]')

# %%
fitkit_data.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366   2016-03-25       11004           7.11             7.11
# 1  1503960366   2016-03-26       17609          11.55            11.55
# 2  1503960366   2016-03-27       12736           8.53             8.53
# 3  1503960366   2016-03-28       13231           8.93             8.93
# 4  1503960366   2016-03-29       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %% [markdown]
# # Q4) Find out in this data that how many unique id's we have.

# %%
fitkit_data['Id'].value_counts().index
# Out:
# Int64Index([4057192912, 4020332650, 1503960366, 1624580081, 2347167796,
#             4702921684, 4445114986, 6962181067, 2320127002, 4558609924,
#             8792009665, 8378563200, 8253242879, 7086361926, 7007744171,
#             2026352035, 5553957443, 8877689391, 1844505072, 2022484408,
#             2873212765, 3977333714, 1927972279, 4319703577, 8053475328,
#             5577150313, 6290855005, 1644430081, 6117666160, 3372868164,
#             6391747486, 6775888955, 2891001357, 8583815059, 4388161847],
#            dtype='int64')

# %%
print(f"There are total {len(list(fitkit_data['Id'].value_counts().index))} Unique Ids ")
# Out:
# There are total 35 Unique Ids

# %% [markdown]
# # Another command for doing finding unique id

# %%
fitkit_data['Id'].unique()
# Out:
# array([1503960366, 1624580081, 1644430081, 1844505072, 1927972279,
#        2022484408, 2026352035, 2320127002, 2347167796, 2873212765,
#        2891001357, 3372868164, 3977333714, 4020332650, 4057192912,
#        4319703577, 4388161847, 4445114986, 4558609924, 4702921684,
#        5553957443, 5577150313, 6117666160, 6290855005, 6391747486,
#        6775888955, 6962181067, 7007744171, 7086361926, 8053475328,
#        8253242879, 8378563200, 8583815059, 8792009665, 8877689391],
#       dtype=int64)

# %%
len(fitkit_data['Id'].unique())
# Out:
# 35

# %% [markdown]
# # Q5) Which id is one of the active id that you have in whole dataset

# %%
fitkit_data.groupby('Id')['VeryActiveMinutes'].sum().idxmax()
# Out:
# 8053475328

# %%
very_active[(very_active == (very_active.max()))]         # this is the active id according to very Acive minutes
# Out:
# Id
# 8053475328    933
# Name: VeryActiveMinutes, dtype: int64

# %% [markdown]
# # Q6) How many of them have not logged there activity find out in terms of number of ids.

# %%
fitkit_data.groupby('Id')['LoggedActivitiesDistance'].sum()<1
# Out:
# Id
# 1503960366     True
# 1624580081     True
# 1644430081     True
# 1844505072     True
# 1927972279     True
# 2022484408     True
# 2026352035     True
# 2320127002     True
# 2347167796     True
# 2873212765     True
# 2891001357    False
# 3372868164     True
# 3977333714     True
# 4020332650     True
# 4057192912     True
# 4319703577     True
# 4388161847     True
# 4445114986     True
# 4558609924     True
# 4702921684     True
# 5553957443     True
# 5577150313     True
# 6117666160     True
# 6290855005     True
# 6391747486    False
# 6775888955     True
# 6962181067    False
# 7007744171    False
# 7086361926     True
# 8053475328     True
# 8253242879     True
# 8378563200    False
# 8583815059     True
# 8792009665     True
# 8877689391     True
# Name: LoggedActivitiesDistance, dtype: bool

# %%
(fitkit_data.groupby('Id')['LoggedActivitiesDistance'].sum()<1).value_counts()
# Out:
# True     30
# False     5
# Name: LoggedActivitiesDistance, dtype: int64

# %% [markdown]
# # or we can write like this

# %%
fitkit_data.groupby('Id')['LoggedActivitiesDistance'].sum().apply(lambda x:x<1).value_counts()
# Out:
# True     30
# False     5
# Name: LoggedActivitiesDistance, dtype: int64

# %% [markdown]
# # Q7) Find out who is the laziest person id that we have in dataset.

# %%
lazy = fitkit_data.groupby('Id')["SedentaryMinutes"].sum()

# %%
lazy[lazy == (lazy.max())]                                         # lazy person according to lightlyAcitveMinutes
# Out:
# Id
# 4057192912    43458
# Name: SedentaryMinutes, dtype: int64

# %%
fitkit_data.groupby('Id')["SedentaryMinutes"].sum().idxmax()        # or we can right like this
# Out:
# 4057192912

# %% [markdown]
# # Q8) Explore over an internet that how much calories burn is required for a healthy person and find out how many healthy person we have in our data set. ( 2200 /day is required)

# %%
fitkit_data.columns
# Out:
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories'],
#       dtype='object')

# %%
count = fitkit_data['Id'].value_counts()

# %%
cal = fitkit_data.groupby('Id')['Calories'].sum()

# %%
mean = cal / count

# %%
mean > 2200              # people burning there calories more then 2200/day on an average
# Out:
# 1503960366    False
# 1624580081    False
# 1644430081     True
# 1844505072    False
# 1927972279     True
# 2022484408     True
# 2026352035    False
# 2320127002    False
# 2347167796    False
# 2873212765    False
# 2891001357     True
# 3372868164    False
# 3977333714    False
# 4020332650     True
# 4057192912    False
# 4319703577    False
# 4388161847    False
# 4445114986    False
# 4558609924    False
# 4702921684     True
# 5553957443    False
# 5577150313     True
# 6117666160    False
# 6290855005    False
# 6391747486    False
# 6775888955     True
# 6962181067    False
# 7007744171     True
# 7086361926    False
# 8053475328     True
# 8253242879    False
# 8378563200     True
# 8583815059     True
# 8792009665    False
# 8877689391     True
# dtype: bool

# %%
(mean > 2200).value_counts()       # Means we have 13 heathy person in our data set
# Out:
# False    22
# True     13
# dtype: int64

# %% [markdown]
# # Q9) How many person are not a regular person with respect to activity try to find out those.

# %%
fitkit_data[fitkit_data['TotalSteps'] == 0].head()
# Out:
#             Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 51  1844505072   2016-04-04           0            0.0              0.0
# 52  1844505072   2016-04-05           0            0.0              0.0
# 59  1844505072   2016-04-12           0            0.0              0.0
# 96  2320127002   2016-04-01           0            0.0              0.0
# 97  2320127002   2016-04-02           0            0.0              0.0
#
#     LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 51                       0.0                 0.0                       0.0
# 52                       0.0                 0.0                       0.0
# 59                       0.0                 0.0                       0.0
# 96                       0.0                 0.0                       0.0
# 97                       0.0                 0.0                       0.0
#
#     LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
list(fitkit_data[fitkit_data['TotalSteps'] == 0]['Id'].unique())
# Out:
# [1844505072,
#  2320127002,
#  2347167796,
#  2873212765,
#  2891001357,
#  4057192912,
#  4319703577,
#  4388161847,
#  4702921684,
#  6117666160,
#  6290855005,
#  6391747486,
#  6775888955,
#  8253242879]

# %%
print(f"{len(list(fitkit_data[fitkit_data['TotalSteps'] == 0]['Id'].unique()))} persons are not regular")
# Out:
# 14 persons are not regular

# %% [markdown]
# # Q10) who is the third most active person in this dataset find out those in pandas

# %%
active_person = fitkit_data.groupby('Id')['VeryActiveMinutes'].sum()

# %%
active_person.sort_values(ascending = False)[2:3]                # 3rd most active person
# Out:
# Id
# 8877689391    802
# Name: VeryActiveMinutes, dtype: int64

# %% [markdown]
# # Q11) who is the 5th most laziest person available in dataset find it out

# %%
fitkit_data.groupby('Id')['SedentaryMinutes'].sum().sort_values(ascending = False)[4:5]
# Out:
# Id
# 1503960366    15387
# Name: SedentaryMinutes, dtype: int64

# %% [markdown]
# # Q12) What is a total acumulative calories burn for a person find out

# %%
fitkit_data.groupby('Id')['Calories'].sum()
# Out:
# Id
# 1503960366    34128
# 1624580081    25705
# 1644430081    29164
# 1844505072    19391
# 1927972279    27048
# 2022484408    29704
# 2026352035    16266
# 2320127002    18385
# 2347167796    30320
# 2873212765    20349
# 2891001357    18187
# 3372868164    18603
# 3977333714    16777
# 4020332650    98412
# 4057192912    60913
# 4319703577    23931
# 4388161847    14442
# 4445114986    31617
# 4558609924    21962
# 4702921684    42322
# 5553957443    21630
# 5577150313    36303
# 6117666160    20993
# 6290855005    21656
# 6391747486    15868
# 6775888955    24523
# 6962181067    29249
# 7007744171    31525
# 7086361926    26124
# 8053475328    31825
# 8253242879    17556
# 8378563200    40274
# 8583815059    19130
# 8792009665    24884
# 8877689391    41414
# Name: Calories, dtype: int64
